# %% [markdown]
# <a href="https://colab.research.google.com/github/motazsaad/infant-cry-care/blob/main/CryCare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ffmpeg
# !pip install git+https://github.com/jiaaro/pydub.git@master
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=66d6e29389175c99502e14ace6bfe2a5faeae37caa091eb5eff8528b04a70bd7
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Collecting git+https://github.com/jiaaro/pydub.git@master
#   Cloning https://github.com/jiaaro/pydub.git (to revision master) to /tmp/pip-req-build-kv65x3xp
#   Running command git clone -q https://github.com/jiaaro/pydub.git /tmp/pip-req-build-kv65x3xp
# Building wheels for collected packages: pydub
#   Building wheel for pydub (setup.py) ... done
#   Created wheel for pydub: filename=pydub-0.25.1-py2.py3-none-any.whl size=32352 sha256=a95efa1dcd745078a23b3cb9c2c589dc8cc6fe8c366add154de917022cfc5c67
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b03ejv0v/wheels/a7/e5/a1/626333b98a5e043f69b7bdd3a989b87b8ccf9005f4b66a6aef
# Successfully built pydub
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import glob
import subprocess
path = '/content/drive/MyDrive/CryCareDataset/'
directories = ['Hungry', 'lower gas', 'burp up', 'Sleepy', 'Uncomfortable'] 
def convertMp3ToWav (directory) :
  for filename in glob.glob(path + directory + '/**.mp3'):
      filewithoutext = filename.split('.')
      wavfile = filewithoutext[0] + '.wav'
      subprocess.call(['ffmpeg', '-i', filename,
                    wavfile])
      
#convert all directories to wav
for directoryName in directories:
  convertMp3ToWav(directoryName)

# %%
#Store all audio files in dictionary where key: filename, value: label
import glob

raw_audio = dict()
def createRawAudio(directories) :
  for directory in directories :
    for filename in glob.glob(path + directory + '/**.wav'):
      raw_audio[filename] = directory
  return raw_audio

raw_audio = createRawAudio(directories)
print (raw_audio)
print(len(raw_audio))
# Out:
# {'/content/drive/MyDrive/CryCareDataset/Hungry/0004006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004007001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0005003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0005001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0004001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0012003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0012002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0012001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0005002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0012005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0012004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0011003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0016001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021007001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0018005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0018004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0018003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0018002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0021004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0018001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023007001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0023006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031001001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031002001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031003001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031004001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031005001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031006001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031007001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031008001.wav': 'Hungry', '/content/drive/MyDrive/CryCareDataset/Hungry/0031009001. ...
# 760

# %%
import pandas as pd
import librosa 
import numpy as np

for i, filename in enumerate(raw_audio):
    if filename.endswith(".wav"):
        audiofile, sr = librosa.load(filename, sr = 11025)
        #cont preprocessing, feature extration
